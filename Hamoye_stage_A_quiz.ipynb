# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Question 1.
# Given the following numpy array
#
# array  = ([[94, 89, 63],
#
#              [93, 92, 48],
#
#              [92, 94, 56]])
#
# How would you select  the elements in bold and italics from the array?

# %%
array  = np.array([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])
array[:2, 1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
fd = pd.read_csv(r"https://raw.githubusercontent.com/mavet10ment/Hamoyequizz1/main/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding='latin-1')

# %% [markdown]
# Question 2. Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
fd.groupby("Element").sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# Question 3. What would be the output for?
#
# S = [['him', 'sell'], [90, 28, 43]]
#
# S[0][1][1]

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# Question 4. Which of the following dataframe methods can be used to access elements across rows and columns?

# %%
fd.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# Question 5. Which of these python data structures is unorderly?
# Answer: set

# %% [markdown]
# Question 6.Which year had the least correlation with ‘Element Code’?

# %%
fd.groupby("Element Code").corr()
# Out:
#                         Area Code  Item Code     Y2014     Y2015     Y2016  \
# Element Code
# 511          Area Code   1.000000        NaN  0.149348  0.149792  0.150292
#              Item Code        NaN        NaN       NaN       NaN       NaN
#              Y2014       0.149348        NaN  1.000000  0.999988  0.999951
#              Y2015       0.149792        NaN  0.999988  1.000000  0.999987
#              Y2016       0.150292        NaN  0.999951  0.999987  1.000000
# ...                           ...        ...       ...       ...       ...
# 5911         Y2014       0.005901   0.056301  1.000000  0.976942  0.992694
#              Y2015       0.007883   0.050526  0.976942  1.000000  0.965195
#              Y2016       0.006203   0.062306  0.992694  0.965195  1.000000
#              Y2017       0.005156   0.063080  0.941934  0.863665  0.963790
#              Y2018       0.004272   0.063211  0.942024  0.863140  0.963378
#
#                            Y2017     Y2018
# ...

# %% [markdown]
# Question 7. What is the total number of unique countries in the dataset?

# %%
len(fd["Area"].unique())
# Out:
# 49

# %% [markdown]
# Question 8. What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
fd.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# Question 9. If you have the following list
#
# lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
#
# col = [‘Age’,’Nationality’,’Overall’]
#
# How do you create a pandas DataFrame using this list, to look like the table below?

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ["Age","Nationality","Overall"]
pd.DataFrame(lst, columns=col, index=[i for i in range (1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# Question 10. What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
round(fd["Y2014"].isnull().sum(), 2), round(fd["Y2014"].isnull().mean()*100, 3)
# Out:
# (1589, 2.607)

# %% [markdown]
# Question 11. Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017

# %%
fd.groupby("Element").sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# Quetion 12. What is the total Protein supply quantity in Madagascar in 2015?

# %%
fd.groupby(["Area"])["Y2015", "Element"].sum()
# Out:
# <ipython-input-31-364e6c20bf59>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   fd.groupby(["Area"])["Y2015", "Element"].sum()
#                                   Y2015
# Area
# Algeria                       324058.40
# Angola                        209565.67
# Benin                         108181.13
# Botswana                       23024.85
# Burkina Faso                  102701.22
# Cabo Verde                     14538.93
# Cameroon                      225220.72
# Central African Republic       28885.34
# Chad                           65835.88
# Comoros                           41.34
# Congo                          40255.51
# Côte d'Ivoire                 211591.29
# Djibouti                       23690.16
# Egypt                         868218.73
# Eswatini                       54072.07
# Ethiopia                      429139.33
# Ethiopia PDR                       0.00
# ...

# %% [markdown]
# Question 13. Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
fd.groupby("Area")[["Area", "Y2017"]].sum()
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %% [markdown]
# Question 14. Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
fd.groupby("Area")[["Area", "Y2017"]].sum()
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %% [markdown]
# Question 15. Which of the following is a python inbuilt module?

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# /usr/local/lib/python3.8/dist-packages/IPython/kernel/__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# /usr/local/lib/python3.8/dist-packages/llvmlite/llvmpy/__init__.py:3: UserWarning: The module `llvmlite.llvmpy` is deprecated and will be removed in the future.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/llvmlite/llvmpy/core.py:8: UserWarning: The module `llvmlite.llvmpy.core` is deprecated and will be removed in the future. Equivalent functionality is provided by `llvmlite.ir`.
#   warnings.warn(
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# ...

# %% [markdown]
# Question 16. Answer the following questions based on the African food production dataset provided by the FAO website already provided
#
# What is the total sum of Wine produced in 2015 and 2018 respectively?
#
# Hint:
#
# Perform a groupby sum aggregation on ‘Item’

# %%
fd.groupby("Item")[["Y2015", "Y2018"]].sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %% [markdown]
# Question 17. Given the following python code, what would the output of the code give?
#
# my_tuppy = (1,2,5,8)
#
# my_tuppy[2] = 6

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-ce1543b3be47> in <module>
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Question 18. A pandas Dataframe with dimensions (100,3) has how many features and observations?
#  Answer: 3 features, 100 observations

# %% [markdown]
# Question 19. How would you check for the number of rows and columns in a pandas DataFrame named df?

# %%
fd.shape
# Out:
# (60943, 12)

# %% [markdown]
# Question 20. Consider the following list of tuples:
#
# y = [(2, 4), (7, 8), (1, 5, 9)]
#
# How would you assign element 8 from the list to a variable x?

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

x = y[1][-1]
